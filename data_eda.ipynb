# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline
import matplotlib
import seaborn as sns
matplotlib.rcParams["figure.figsize"]=(20,10)

# %%
df = pd.read_csv('data_cleaned.csv')

# %%
import matplotlib
matplotlib.rcParams["figure.figsize"]=(20,10)
plt.hist(df.price_per_sqft, rwidth = 0.8)
plt.xlabel("Price Per Square Feet")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df.bath.value_counts()
# Out:
# 2.0     4508
# 3.0     1804
# 1.0      537
# 4.0      508
# 5.0      181
# 6.0       88
# 7.0       23
# 8.0       16
# 9.0        7
# 12.0       3
# 13.0       1
# 14.0       1
# Name: bath, dtype: int64

# %%
df=df.drop(['Unnamed: 0','size','price_per_sqft'], axis =1 )

# %%
df[df.bath>10]
# Out:
#                  area_type        location  total_sqft  bath  price  bhk
# 676             Plot  Area   BTM 1st Stage      3300.0  14.0  500.0    9
# 5209  Super built-up  Area  Neeladri Nagar      4000.0  12.0  160.0   10
# 7549  Super built-up  Area           other     12000.0  12.0  525.0   10
# 7604  Super built-up  Area           other      6000.0  12.0  150.0   11
# 7626  Super built-up  Area           other      5425.0  13.0  275.0   13

# %%
plt.hist(df.bath, rwidth = 0.8)
plt.xlabel("Number of bathrooms")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df[df.bath>df.bhk+2]
# Out:
#                  area_type           location  total_sqft  bath   price  bhk
# 676             Plot  Area      BTM 1st Stage      3300.0  14.0   500.0    9
# 1681        Built-up  Area      Chikkabanavar      2460.0   7.0    80.0    4
# 5144        Built-up  Area         Nagasandra      7000.0   8.0   450.0    4
# 6212  Super built-up  Area  Sathya Sai Layout     11338.0   9.0  1000.0    6
# 6610  Super built-up  Area        Thanisandra      1806.0   6.0   116.0    3

# %%
df.area_type.hist()
# Out:
# <AxesSubplot:>

# %%
df.bhk.hist()
plt.xlabel("Number of bedrooms")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df[['total_sqft','bath','price','bhk']].corr()
# Out:
#             total_sqft      bath     price       bhk
# total_sqft    1.000000  0.659462  0.796714  0.640614
# bath          0.659462  1.000000  0.531686  0.879047
# price         0.796714  0.531686  1.000000  0.493783
# bhk           0.640614  0.879047  0.493783  1.000000

# %%
# correlation heatmap
x=['total_sqft','bath','price','bhk']
cmap = sns.diverging_palette(220, 20, as_cmap=True)
sns.heatmap(df[x].corr(), cmap = cmap,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['area_type', 'location', 'total_sqft', 'bath', 'price', 'bhk'], dtype='object')
